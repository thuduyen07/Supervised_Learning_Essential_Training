# %%
#import all libraries

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn import decomposition
from sklearn import tree
from sklearn.pipeline import Pipeline
import pydotplus
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import matplotlib.image as pltimg
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler

# %%
# load Occupancy Data

room1 = pd.read_csv("../../Data/datatest.txt", sep = ',', header = 0)
room2 = pd.read_csv("../../Data/datatraining.txt", sep = ',', header = 0)
room = pd.concat([room1, room2])
features = ['Light', 'CO2', 'Temperature', 'HumidityRatio', 'Humidity']
X = room[features]
y = room['Occupancy']
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.30, 
                                                    random_state=42)
dtree = DecisionTreeClassifier(random_state=0)
dtree = dtree.fit(X_train, y_train)
data = tree.export_graphviz(dtree, out_file=None, feature_names=features)
graph = pydotplus.graph_from_dot_data(data)
graph.write_png('mydecisiontree.png')

img=pltimg.imread('mydecisiontree.png')
imgplot = plt.imshow(img)
plt.show()

# %%
# Print decision tree digraph (saved as data in the cell above)
# Out:
# digraph Tree {
# node [shape=box] ;
# 0 [label="Light <= 369.875\ngini = 0.373\nsamples = 7565\nvalue = [5687, 1878]"] ;
# 1 [label="Humidity <= 37.74\ngini = 0.004\nsamples = 5592\nvalue = [5582, 10]"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label="Light <= 212.5\ngini = 0.003\nsamples = 5590\nvalue = [5582, 8]"] ;
# 1 -> 2 ;
# 3 [label="CO2 <= 1244.5\ngini = 0.0\nsamples = 5403\nvalue = [5402, 1]"] ;
# 2 -> 3 ;
# 4 [label="gini = 0.0\nsamples = 5359\nvalue = [5359, 0]"] ;
# 3 -> 4 ;
# 5 [label="CO2 <= 1247.75\ngini = 0.044\nsamples = 44\nvalue = [43, 1]"] ;
# 3 -> 5 ;
# 6 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 5 -> 6 ;
# 7 [label="gini = 0.0\nsamples = 43\nvalue = [43, 0]"] ;
# 5 -> 7 ;
# 8 [label="CO2 <= 469.208\ngini = 0.072\nsamples = 187\nvalue = [180, 7]"] ;
# 2 -> 8 ;
# 9 [label="Light <= 218.1\ngini = 0.022\nsamples = 181\nvalue = [179, 2]"] ;
# 8 -> 9 ;
# 10 [label="HumidityRatio <= 0.004\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 9 -> 10 ;
# 11 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 10 -> 11 ;
# 12 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 10 -> 12 ;
# 13 [label="Light <= 355.875\ngini = 0.011\nsamples = 178\nvalue = [177, 1]"] ;
# 9 -> 13 ;
# 14 [label="gini = 0.0\nsamples = 168\nvalue = [168, 0]"] ;
# 13 -> 14 ;
# 15 [label="Temperature <= 21.495\ngini = 0.18\nsamples = 10\nvalue = [9, 1]"] ;
# 13 -> 15 ;
# 16 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 15 -> 16 ;
# 17 [label="gini = 0.0\nsamples = 9\nvalue = [9, 0]"] ;
# 15 -> 17 ;
# 18 [label="HumidityRatio <= 0.005\ngini = 0.278\nsamples = 6\nvalue = [1, 5]"] ;
# 8 -> 18 ;
# 19 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]"] ;
# 18 -> 19 ;
# 20 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 18 -> 20 ;
# 21 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 1 -> 21 ;
# 22 [label="CO2 <= 456.333\ngini = 0.101\nsamples = 1973\nvalue = [105, 1868]"] ;
# 0 -> 22 [labeldistance=2.5, labelangle=-45, headlabel="False"] ;
# 23 [label="Light <= 406.167\ngini = 0.18\nsamples = 10\nvalue = [9, 1]"] ;
# 22 -> 23 ;
# 24 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 23 -> 24 ;
# 25 [label="gini = 0.0\nsamples = 9\nvalue = [9, 0]"] ;
# 23 -> 25 ;
# 26 [label="Humidity <= 26.894\ngini = 0.093\nsamples = 1963\nvalue = [96, 1867]"] ;
# 22 -> 26 ;
# 27 [label="Temperature <= 22.234\ngini = 0.153\nsamples = 1068\nvalue = [89, 979]"] ;
# 26 -> 27 ;
# 28 [label="CO2 <= 470.45\ngini = 0.075\nsamples = 765\nvalue = [30, 735]"] ;
# 27 -> 28 ;
# 29 [label="Temperature <= 20.245\ngini = 0.494\nsamples = 9\nvalue = [4, 5]"] ;
# 28 -> 29 ;
# 30 [label="HumidityRatio <= 0.003\ngini = 0.278\nsamples = 6\nvalue = [1, 5]"] ;
# 29 -> 30 ;
# 31 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 30 -> 31 ;
# 32 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]"] ;
# 30 -> 32 ;
# 33 [label="gini = 0.0\nsamples = 3\nvalue = [3, 0]"] ;
# 29 -> 33 ;
# 34 [label="CO2 <= 777.875\ngini = 0.066\nsamples = 756\nvalue = [26, 730]"] ;
# 28 -> 34 ;
# 35 [label="Humidity <= 25.283\ngini = 0.124\nsamples = 301\nvalue = [20, 281]"] ;
# 34 -> 35 ;
# 36 [label="Humidity <= 19.404\ngini = 0.082\nsamples = 279\nvalue = [12, 267]"] ;
# 35 -> 36 ;
# 37 [label="CO2 <= 646.25\ngini = 0.257\nsamples = 33\nvalue = [5, 28]"] ;
# 36 -> 37 ;
# 38 [label="gini = 0.0\nsamples = 23\nvalue = [0, 23]"] ;
# 37 -> 38 ;
# 39 [label="CO2 <= 653.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]"] ;
# 37 -> 39 ;
# 40 [label="gini = 0.0\nsamples = 5\nvalue = [5, 0]"] ;
# 39 -> 40 ;
# 41 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]"] ;
# 39 -> 41 ;
# 42 [label="CO2 <= 529.5\ngini = 0.055\nsamples = 246\nvalue = [7, 239]"] ;
# 36 -> 42 ;
# 43 [label="Humidity <= 24.042\ngini = 0.252\nsamples = 27\nvalue = [4, 23]"] ;
# 42 -> 43 ;
# 44 [label="gini = 0.0\nsamples = 23\nvalue = [0, 23]"] ;
# 43 -> 44 ;
# 45 [label="gini = 0.0\nsamples = 4\nvalue = [4, 0]"] ;
# 43 -> 45 ;
# 46 [label="HumidityRatio <= 0.004\ngini = 0.027\nsamples = 219\nvalue = [3, 216]"] ;
# 42 -> 46 ;
# 47 [label="HumidityRatio <= 0.004\ngini = 0.01\nsamples = 196\nvalue = [1, 195]"] ;
# 46 -> 47 ;
# 48 [label="gini = 0.0\nsamples = 141\nvalue = [0, 141]"] ;
# 47 -> 48 ;
# 49 [label="Humidity <= 23.945\ngini = 0.036\nsamples = 55\nvalue = [1, 54]"] ;
# 47 -> 49 ;
# 50 [label="CO2 <= 650.75\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 49 -> 50 ;
# 51 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 50 -> 51 ;
# 52 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 50 -> 52 ;
# 53 [label="gini = 0.0\nsamples = 53\nvalue = [0, 53]"] ;
# 49 -> 53 ;
# 54 [label="Humidity <= 24.874\ngini = 0.159\nsamples = 23\nvalue = [2, 21]"] ;
# 46 -> 54 ;
# 55 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 54 -> 55 ;
# 56 [label="gini = 0.0\nsamples = 21\nvalue = [0, 21]"] ;
# 54 -> 56 ;
# 57 [label="Temperature <= 20.986\ngini = 0.463\nsamples = 22\nvalue = [8, 14]"] ;
# 35 -> 57 ;
# 58 [label="gini = 0.0\nsamples = 10\nvalue = [0, 10]"] ;
# 57 -> 58 ;
# 59 [label="HumidityRatio <= 0.004\ngini = 0.444\nsamples = 12\nvalue = [8, 4]"] ;
# 57 -> 59 ;
# 60 [label="gini = 0.0\nsamples = 8\nvalue = [8, 0]"] ;
# 59 -> 60 ;
# 61 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"] ;
# 59 -> 61 ;
# 62 [label="Humidity <= 20.529\ngini = 0.026\nsamples = 455\nvalue = [6, 449]"] ;
# 34 -> 62 ;
# 63 [label="Humidity <= 20.512\ngini = 0.131\nsamples = 57\nvalue = [4, 53]"] ;
# 62 -> 63 ;
# 64 [label="Humidity <= 20.498\ngini = 0.101\nsamples = 56\nvalue = [3, 53]"] ;
# 63 -> 64 ;
# 65 [label="Light <= 474.167\ngini = 0.04\nsamples = 49\nvalue = [1, 48]"] ;
# 64 -> 65 ;
# 66 [label="Light <= 472.75\ngini = 0.198\nsamples = 9\nvalue = [1, 8]"] ;
# 65 -> 66 ;
# 67 [label="gini = 0.0\nsamples = 8\nvalue = [0, 8]"] ;
# 66 -> 67 ;
# 68 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 66 -> 68 ;
# 69 [label="gini = 0.0\nsamples = 40\nvalue = [0, 40]"] ;
# 65 -> 69 ;
# 70 [label="CO2 <= 808.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]"] ;
# 64 -> 70 ;
# 71 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 70 -> 71 ;
# 72 [label="CO2 <= 821.833\ngini = 0.5\nsamples = 4\nvalue = [2, 2]"] ;
# 70 -> 72 ;
# 73 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 72 -> 73 ;
# 74 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 72 -> 74 ;
# 75 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 63 -> 75 ;
# 76 [label="Humidity <= 26.537\ngini = 0.01\nsamples = 398\nvalue = [2, 396]"] ;
# 62 -> 76 ;
# 77 [label="gini = 0.0\nsamples = 361\nvalue = [0, 361]"] ;
# 76 -> 77 ;
# 78 [label="Humidity <= 26.562\ngini = 0.102\nsamples = 37\nvalue = [2, 35]"] ;
# 76 -> 78 ;
# 79 [label="HumidityRatio <= 0.004\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 78 -> 79 ;
# 80 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 79 -> 80 ;
# 81 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 79 -> 81 ;
# 82 [label="CO2 <= 1039.0\ngini = 0.056\nsamples = 35\nvalue = [1, 34]"] ;
# 78 -> 82 ;
# 83 [label="CO2 <= 982.05\ngini = 0.219\nsamples = 8\nvalue = [1, 7]"] ;
# 82 -> 83 ;
# 84 [label="gini = 0.0\nsamples = 7\nvalue = [0, 7]"] ;
# 83 -> 84 ;
# 85 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 83 -> 85 ;
# 86 [label="gini = 0.0\nsamples = 27\nvalue = [0, 27]"] ;
# 82 -> 86 ;
# 87 [label="Light <= 427.1\ngini = 0.314\nsamples = 303\nvalue = [59, 244]"] ;
# 27 -> 87 ;
# 88 [label="Temperature <= 22.404\ngini = 0.397\nsamples = 22\nvalue = [16, 6]"] ;
# 87 -> 88 ;
# 89 [label="Humidity <= 24.706\ngini = 0.278\nsamples = 6\nvalue = [1, 5]"] ;
# 88 -> 89 ;
# 90 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 89 -> 90 ;
# 91 [label="gini = 0.0\nsamples = 5\nvalue = [0, 5]"] ;
# 89 -> 91 ;
# 92 [label="Light <= 424.133\ngini = 0.117\nsamples = 16\nvalue = [15, 1]"] ;
# 88 -> 92 ;
# 93 [label="gini = 0.0\nsamples = 13\nvalue = [13, 0]"] ;
# 92 -> 93 ;
# 94 [label="Humidity <= 25.09\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 92 -> 94 ;
# 95 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 94 -> 95 ;
# 96 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 94 -> 96 ;
# 97 [label="Temperature <= 22.303\ngini = 0.259\nsamples = 281\nvalue = [43, 238]"] ;
# 87 -> 97 ;
# 98 [label="CO2 <= 892.375\ngini = 0.496\nsamples = 44\nvalue = [20, 24]"] ;
# 97 -> 98 ;
# 99 [label="CO2 <= 810.25\ngini = 0.095\nsamples = 20\nvalue = [19, 1]"] ;
# 98 -> 99 ;
# 100 [label="Humidity <= 25.945\ngini = 0.245\nsamples = 7\nvalue = [6, 1]"] ;
# 99 -> 100 ;
# 101 [label="gini = 0.0\nsamples = 6\nvalue = [6, 0]"] ;
# 100 -> 101 ;
# 102 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 100 -> 102 ;
# 103 [label="gini = 0.0\nsamples = 13\nvalue = [13, 0]"] ;
# 99 -> 103 ;
# 104 [label="Light <= 587.583\ngini = 0.08\nsamples = 24\nvalue = [1, 23]"] ;
# 98 -> 104 ;
# 105 [label="gini = 0.0\nsamples = 22\nvalue = [0, 22]"] ;
# 104 -> 105 ;
# 106 [label="HumidityRatio <= 0.004\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 104 -> 106 ;
# 107 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 106 -> 107 ;
# 108 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 106 -> 108 ;
# 109 [label="Light <= 472.75\ngini = 0.175\nsamples = 237\nvalue = [23, 214]"] ;
# 97 -> 109 ;
# 110 [label="Light <= 428.667\ngini = 0.023\nsamples = 87\nvalue = [1, 86]"] ;
# 109 -> 110 ;
# 111 [label="HumidityRatio <= 0.004\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"] ;
# 110 -> 111 ;
# 112 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 111 -> 112 ;
# 113 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 111 -> 113 ;
# 114 [label="gini = 0.0\nsamples = 84\nvalue = [0, 84]"] ;
# 110 -> 114 ;
# 115 [label="Light <= 640.75\ngini = 0.25\nsamples = 150\nvalue = [22, 128]"] ;
# 109 -> 115 ;
# 116 [label="Temperature <= 23.227\ngini = 0.423\nsamples = 69\nvalue = [21, 48]"] ;
# 115 -> 116 ;
# 117 [label="Temperature <= 22.642\ngini = 0.492\nsamples = 48\nvalue = [21, 27]"] ;
# 116 -> 117 ;
# 118 [label="CO2 <= 907.25\ngini = 0.219\nsamples = 16\nvalue = [2, 14]"] ;
# 117 -> 118 ;
# 119 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 118 -> 119 ;
# 120 [label="gini = 0.0\nsamples = 14\nvalue = [0, 14]"] ;
# 118 -> 120 ;
# 121 [label="CO2 <= 894.867\ngini = 0.482\nsamples = 32\nvalue = [19, 13]"] ;
# 117 -> 121 ;
# 122 [label="gini = 0.0\nsamples = 8\nvalue = [0, 8]"] ;
# 121 -> 122 ;
# 123 [label="HumidityRatio <= 0.004\ngini = 0.33\nsamples = 24\nvalue = [19, 5]"] ;
# 121 -> 123 ;
# 124 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 123 -> 124 ;
# 125 [label="CO2 <= 1119.458\ngini = 0.236\nsamples = 22\nvalue = [19, 3]"] ;
# 123 -> 125 ;
# 126 [label="Temperature <= 22.658\ngini = 0.172\nsamples = 21\nvalue = [19, 2]"] ;
# 125 -> 126 ;
# 127 [label="CO2 <= 1049.375\ngini = 0.5\nsamples = 2\nvalue = [1, 1]"] ;
# 126 -> 127 ;
# 128 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 127 -> 128 ;
# 129 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 127 -> 129 ;
# 130 [label="CO2 <= 919.708\ngini = 0.1\nsamples = 19\nvalue = [18, 1]"] ;
# 126 -> 130 ;
# 131 [label="Light <= 548.208\ngini = 0.444\nsamples = 3\nvalue = [2, 1]"] ;
# 130 -> 131 ;
# 132 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 131 -> 132 ;
# 133 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 131 -> 133 ;
# 134 [label="gini = 0.0\nsamples = 16\nvalue = [16, 0]"] ;
# 130 -> 134 ;
# 135 [label="gini = 0.0\nsamples = 1\nvalue = [0, 1]"] ;
# 125 -> 135 ;
# 136 [label="gini = 0.0\nsamples = 21\nvalue = [0, 21]"] ;
# 116 -> 136 ;
# 137 [label="HumidityRatio <= 0.005\ngini = 0.024\nsamples = 81\nvalue = [1, 80]"] ;
# 115 -> 137 ;
# 138 [label="HumidityRatio <= 0.005\ngini = 0.095\nsamples = 20\nvalue = [1, 19]"] ;
# 137 -> 138 ;
# 139 [label="gini = 0.0\nsamples = 19\nvalue = [0, 19]"] ;
# 138 -> 139 ;
# 140 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 138 -> 140 ;
# 141 [label="gini = 0.0\nsamples = 61\nvalue = [0, 61]"] ;
# 137 -> 141 ;
# 142 [label="CO2 <= 493.333\ngini = 0.016\nsamples = 895\nvalue = [7, 888]"] ;
# 26 -> 142 ;
# 143 [label="Light <= 399.333\ngini = 0.463\nsamples = 11\nvalue = [4, 7]"] ;
# 142 -> 143 ;
# 144 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 143 -> 144 ;
# 145 [label="Humidity <= 33.302\ngini = 0.346\nsamples = 9\nvalue = [2, 7]"] ;
# 143 -> 145 ;
# 146 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]"] ;
# 145 -> 146 ;
# 147 [label="Temperature <= 20.361\ngini = 0.48\nsamples = 5\nvalue = [2, 3]"] ;
# 145 -> 147 ;
# 148 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]"] ;
# 147 -> 148 ;
# 149 [label="gini = 0.0\nsamples = 3\nvalue = [0, 3]"] ;
# 147 -> 149 ;
# 150 [label="Light <= 586.15\ngini = 0.007\nsamples = 884\nvalue = [3, 881]"] ;
# 142 -> 150 ;
# 151 [label="Light <= 535.107\ngini = 0.002\nsamples = 873\nvalue = [1, 872]"] ;
# 150 -> 151 ;
# 152 [label="gini = 0.0\nsamples = 820\nvalue = [0, 820]"] ;
# 151 -> 152 ;
# 153 [label="Light <= 536.024\ngini = 0.037\nsamples = 53\nvalue = [1, 52]"] ;
# 151 -> 153 ;
# 154 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 153 -> 154 ;
# 155 [label="gini = 0.0\nsamples = 52\nvalue = [0, 52]"] ;
# 153 -> 155 ;
# 156 [label="Light <= 590.25\ngini = 0.298\nsamples = 11\nvalue = [2, 9]"] ;
# 150 -> 156 ;
# 157 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 156 -> 157 ;
# 158 [label="Humidity <= 27.272\ngini = 0.18\nsamples = 10\nvalue = [1, 9]"] ;
# 156 -> 158 ;
# 159 [label="gini = 0.0\nsamples = 7\nvalue = [0, 7]"] ;
# 158 -> 159 ;
# 160 [label="Light <= 602.3\ngini = 0.444\nsamples = 3\nvalue = [1, 2]"] ;
# 158 -> 160 ;
# 161 [label="gini = 0.0\nsamples = 2\nvalue = [0, 2]"] ;
# 160 -> 161 ;
# 162 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]"] ;
# 160 -> 162 ;
# }

# %%
y_pred = dtree.predict(X_test)

# %%
# Print confusion matric and classification report
# Out:
# [[2407   13]
#  [  14  809]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2420
#            1       0.98      0.98      0.98       823
#
#     accuracy                           0.99      3243
#    macro avg       0.99      0.99      0.99      3243
# weighted avg       0.99      0.99      0.99      3243

# %%
# StandardScaler is used to remove the outliners

std_slc = StandardScaler()
pca = decomposition.PCA()
dtree2 = tree.DecisionTreeClassifier()

# %%
# Create pipeline to pass multuple parameters to gridsearch

pipe = Pipeline(steps=[('std_slc', std_slc),
                           ('pca', pca),
                           ('dec_tree', dtree2)])

# %%
# PCA reduces the dimension of features
n_components = list(range(1,X.shape[1]+1,1))

# %%
criterion = ['gini', 'entropy']
max_depth = [2,4,6,8,10,12,24,48]

# %%
parameters = dict(pca__n_components=n_components,
                      dec_tree__criterion=criterion,
                      dec_tree__max_depth=max_depth)

# %%
clf_GS = GridSearchCV(pipe, parameters)
clf_GS.fit(X, y)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('std_slc',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('pca',
#                                         PCA(copy=True, iterated_power='auto',
#                                             n_components=None,
#                                             random_state=None,
#                                             svd_solver='auto', tol=0.0,
#                                             whiten=False)),
#                                        ('dec_tree',
#                                         DecisionTreeClassifier(ccp_alpha=0.0,
#                                                                class_weight=None,
#                                                                criterion='gini',
#                                                                max_...
#                                                                min_samples_split=2,
#                                                                min_weight_fraction_leaf=0.0,
#                                                                presort='deprecated',
#                                                                random_state=None,
#                                                                splitter='best'))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'dec_tree__criterion': ['gini', 'entropy'],
#                          'dec_tree__max_depth': [2, 4, 6, 8, 10, 12, 24, 48],
#                          'pca__n_components': [1, 2, 3, 4, 5]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print('Best Criterion:', clf_GS.best_estimator_.get_params()['dec_tree__criterion'])
print('Best max_depth:', clf_GS.best_estimator_.get_params()['dec_tree__max_depth'])
print('Best Number Of Components:', clf_GS.best_estimator_.get_params()['pca__n_components'])
print(); print(clf_GS.best_estimator_.get_params()['dec_tree'])
# Out:
# Best Criterion: entropy
# Best max_depth: 6
# Best Number Of Components: 4
#
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=6, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
# dtree = DecisionTreeClassifier(random_state=0, max_depth= 5)
# dtree = DecisionTreeClassifier(random_state=0, max_depth= 15)
# dtree = DecisionTreeClassifier(random_state=0,min_samples_leaf= 200)
# dtree = DecisionTreeClassifier(random_state=0,min_samples_leaf= 425)
